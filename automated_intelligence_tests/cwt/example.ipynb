# %% [markdown]
# # CWT – Creative Writing Task
#
# Generate a short-story prompt that must include one, two or three cue words.
#
# **Usage**
# 1. Call `instruct.instruct(cues=None, n_words=3, seed=None)`.
#    - If `cues` is omitted a random set of length `n_words` is sampled from the standard sets (1, 2 or 3).
# 2. The returned `response_format` already contains the original `cues` so later evaluation has full context.
# 3. Collect a 5–6 sentence creative story that uses every cue word.
#
# **Note:** `evaluate` is still a placeholder – creativity scoring (e.g. DSI) will be added later.
#
# **Source:** Johnson et al. (2023), Behavior Research Methods. DOI: 10.3758/s13428-022-01986-2

# %%
import instruct, evaluate

# Random 3-word cues (default)
stim = instruct.instruct(seed=0)
print("=== n_words=3 (default) ===")
for k, v in stim.items():
    print(k, ":", v)
print()

# 1-word
stim = instruct.instruct(n_words=1, seed=0)
print("=== n_words=1 ===")
for k, v in stim.items():
    print(k, ":", v)
print()

# 2-word
stim = instruct.instruct(n_words=2, seed=0)
print("=== n_words=2 ===")
for k, v in stim.items():
    print(k, ":", v)
print()

# Fixed cues
stim = instruct.instruct(cues=["fixed", "cue", "task"])
print("=== fixed cues ===")
for k, v in stim.items():
    print(k, ":", v)
print()
# Out:
# === n_words=3 (default) ===
# test : cwt
# cues : ['year', 'week', 'embark']
# n_words : 3
# instructions : Write a short creative story of about five to six sentences that includes all of these word(s): year, week, embark.
#
# Rules:
# 1. Use your imagination and be creative.
# 2. Include every cue word at least once.
# 3. Aim for five to six sentences.
#
# Notes:
# Return only the story text itself. Do not include a title, headings, or any commentary.
# response_format : {'cues': ['year', 'week', 'embark'], 'story': '...'}
#
# === n_words=1 ===
# test : cwt
# cues : ['2305']
# n_words : 1
# instructions : Write a short creative story of about five to six sentences that includes all of these word(s): 2305.
#
# Rules:
# 1. Use your imagination and be creative.
# 2. Include every cue word at least once.
# 3. Aim for five to six sentences.
#
# Notes:
# Return only the story text itself. Do not include a title, headings, or any commentary.
# ...

# %% [markdown]
# ### Expected response shape
#
# ```python
# {
#   "cues": ["moon", "river", "whisper"],
#   "story": "Five to six sentences that include every cue word …"
# }
# ```
#
# The original cues travel with the story so evaluation can verify that every cue appears and judge appropriateness without external lookup.
